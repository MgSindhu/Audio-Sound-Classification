# %% [markdown]
# # Audio Classification

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename = r"C:\Users\sindh\OneDrive\Documents\Projects\Audio Classification\UrbanSound8K\audio\fold4\7064-6-1-0.wav"

# %%
import IPython.display as ipd
import librosa
import librosa.display

# %%
# bullet sound
plt.figure(figsize = (14, 5))
data, sample_rate = librosa.load(filename)
librosa.display.waveshow(data, sr = sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample_rate
# Out:
# 22050

# %% [markdown]
# stereo - when there are different sounds in one particular audio at same time
#
# mono - same saound on emtire audio
#
# librosa try to normalize entire dataset and it will try to get data into single sample rate

# %%
from scipy.io import wavfile as wav
wav_sample_rate, wav_audio = wav.read(filename)

# %%
wav_sample_rate
# Out:
# 44100

# %% [markdown]
# Sound wave signals is represented in integer values and that is what is called wav_audio and by using scipy the data is not normalizing

# %%
wav_audio
# Out:
# array([[ 340,  -71],
#        [ 428, -232],
#        [ 476, -352],
#        ...,
#        [ 407,  301],
#        [ 344,  219],
#        [ 297,  165]], dtype=int16)

# %%
data
# Out:
# array([0.0028339 , 0.00257723, 0.00425194, ..., 0.0087251 , 0.01050946,
#        0.00926754], dtype=float32)

# %%
import pandas as pd
metadata = pd.read_csv("UrbanSound8K/metadata/UrbanSound8K.csv")
metadata.head()
# Out:
#       slice_file_name    fsID  start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032    0.0   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263   58.5  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263   60.5  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263   63.0  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263   68.5  72.500000         1     5        2
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing

# %%
# Check whether the dataset is imbalanced
metadata['class'].value_counts()
# Out:
# dog_bark            1000
# children_playing    1000
# air_conditioner     1000
# street_music        1000
# engine_idling       1000
# jackhammer          1000
# drilling            1000
# siren                929
# car_horn             429
# gun_shot             374
# Name: class, dtype: int64
